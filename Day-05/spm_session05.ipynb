# %%
#import pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '0.23.0'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit: None
# python: 3.6.5.final.0
# python-bits: 64
# OS: Windows
# OS-release: 10
# machine: AMD64
# processor: Intel64 Family 6 Model 60 Stepping 3, GenuineIntel
# byteorder: little
# LC_ALL: None
# LANG: None
# LOCALE: None.None
#
# pandas: 0.23.0
# pytest: 3.5.1
# pip: 10.0.1
# setuptools: 39.1.0
# Cython: 0.28.2
# numpy: 1.14.3
# scipy: 1.1.0
# pyarrow: None
# xarray: None
# IPython: 6.4.0
# sphinx: 1.7.4
# patsy: 0.5.0
# dateutil: 2.7.3
# pytz: 2018.4
# blosc: None
# bottleneck: 1.2.1
# tables: 3.4.3
# numexpr: 2.6.5
# feather: None
# matplotlib: 2.2.2
# openpyxl: 2.5.3
# xlrd: 1.1.0
# xlwt: 1.3.0
# xlsxwriter: 1.0.4
# lxml: 4.2.1
# bs4: 4.6.0
# html5lib: 1.0.1
# sqlalchemy: 1.2.7
# pymysql: 0.8.1
# psycopg2: None
# jinja2: 2.10
# s3fs: None
# fastparquet: None
# pandas_gbq: None
# pandas_datareader: None

# %%
df1 = pd.read_csv("imdbratings.csv")

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df1.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
type(df1.genre)
# Out:
# pandas.core.series.Series

# %%
type(df1.star_rating)
# Out:
# pandas.core.series.Series

# %%
df1.star_rating
# Out:
# 0      9.3
# 1      9.2
# 2      9.1
# 3      9.0
# 4      8.9
# 5      8.9
# 6      8.9
# 7      8.9
# 8      8.9
# 9      8.9
# 10     8.8
# 11     8.8
# 12     8.8
# 13     8.8
# 14     8.8
# 15     8.7
# 16     8.7
# 17     8.7
# 18     8.7
# 19     8.7
# 20     8.7
# 21     8.7
# 22     8.7
# 23     8.7
# 24     8.7
# 25     8.6
# 26     8.6
# 27     8.6
# 28     8.6
# 29     8.6
#       ...
# 949    7.4
# 950    7.4
# 951    7.4
# 952    7.4
# 953    7.4
# 954    7.4
# 955    7.4
# 956    7.4
# 957    7.4
# 958    7.4
# 959    7.4
# 960    7.4
# 961    7.4
# 962    7.4
# 963    7.4
# 964    7.4
# 965    7.4
# 966    7.4
# 967    7.4
# 968    7.4
# 969    7.4
# 970    7.4
# 971    7.4
# 972    7.4
# 973    7.4
# 974    7.4
# 975    7.4
# 976    7.4
# 977    7.4
# 978    7.4
# Name: star_rating, Length: 979, dtype: float64

# %%
df1.star_rating.head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# Name: star_rating, dtype: float64

# %%
df1.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df1[['star_rating', 'title']].head()
# Out:
#    star_rating                     title
# 0          9.3  The Shawshank Redemption
# 1          9.2             The Godfather
# 2          9.1    The Godfather: Part II
# 3          9.0           The Dark Knight
# 4          8.9              Pulp Fiction

# %%
df1[['star_rating', 'title', 'duration']].head()
# Out:
#    star_rating                     title  duration
# 0          9.3  The Shawshank Redemption       142
# 1          9.2             The Godfather       175
# 2          9.1    The Godfather: Part II       200
# 3          9.0           The Dark Knight       152
# 4          8.9              Pulp Fiction       154

# %%
type(df1[['star_rating', 'title', 'duration']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1[  ['star_rating']   ])
# Out:
# pandas.core.frame.DataFrame

# %%
df1['star_rating'].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# Name: star_rating, dtype: float64

# %%
type(df1['star_rating'])
# Out:
# pandas.core.series.Series

# %%
df1[  ['star_rating']   ].head()
# Out:
#    star_rating
# 0          9.3
# 1          9.2
# 2          9.1
# 3          9.0
# 4          8.9

# %%
df1['star_rating'].head()
# Out:
# 0    9.3
# 1    9.2
# 2    9.1
# 3    9.0
# 4    8.9
# Name: star_rating, dtype: float64

# %%
# How many ways we can display Column 'Title'
# 1.    df1.title       -> Series
# 2.    df1['title']    -> Series
# 3.    df1[['title']]  -> DataFrame

# %%
df1.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df1.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
df1.shape
# Out:
# (979, 6)

# %%
df1.shape[0]
# Out:
# 979

# %%
df1.shape[1]
# Out:
# 6

# %%
df1.genre.head()
# Out:
# 0     Crime
# 1     Crime
# 2     Crime
# 3    Action
# 4     Crime
# Name: genre, dtype: object

# %%
df1.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
df1.star_rating.value_counts()
# Out:
# 7.6    124
# 7.8    116
# 7.7    113
# 7.5    108
# 8.1    103
# 8.0     97
# 7.9     75
# 8.2     51
# 7.4     49
# 8.3     43
# 8.4     37
# 8.5     23
# 8.6     15
# 8.7     10
# 8.9      6
# 8.8      5
# 9.3      1
# 9.2      1
# 9.1      1
# 9.0      1
# Name: star_rating, dtype: int64

# %%
df1.duration.head()
# Out:
# 0    142
# 1    175
# 2    200
# 3    152
# 4    154
# Name: duration, dtype: int64

# %%
df1.duration.sort_values()
# Out:
# 389     64
# 338     66
# 258     67
# 293     68
# 88      68
# 742     69
# 351     70
# 938     75
# 405     75
# 303     76
# 713     78
# 864     78
# 489     78
# 535     79
# 513     80
# 853     80
# 533     80
# 283     80
# 297     80
# 622     80
# 117     81
# 541     81
# 738     81
# 789     81
# 330     81
# 595     82
# 306     82
# 174     83
# 759     83
# 766     83
#       ...
# 361    181
# 166    182
# 109    183
# 245    184
# 132    186
# 611    187
# 318    188
# 184    188
# 89     189
# 316    189
# 40     189
# 671    191
# 220    191
# 424    193
# 620    194
# 8      195
# 385    197
# 335    197
# 2      200
# 7      201
# 630    202
# 767    205
# 17     207
# 204    212
# 85     216
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, Length: 979, dtype: int64

# %%
df1.duration.sort_values(ascending=False).head()
# Out:
# 476    242
# 157    238
# 78     229
# 142    224
# 445    220
# Name: duration, dtype: int64

# %%
df1.duration.sort_values(ascending=True).tail()
# Out:
# 445    220
# 142    224
# 78     229
# 157    238
# 476    242
# Name: duration, dtype: int64

# %%
df1.genre.head()
# Out:
# 0     Crime
# 1     Crime
# 2     Crime
# 3    Action
# 4     Crime
# Name: genre, dtype: object

# %%
df1.genre=='Mystery'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965     True
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: genre, Length: 979, dtype: bool

# %%
df1[df1.genre=='Mystery']
# Out:
#      star_rating                     title content_rating    genre  duration  \
# 38           8.6               Rear Window       APPROVED  Mystery       112
# 46           8.5                   Memento              R  Mystery       113
# 76           8.4                   Vertigo       APPROVED  Mystery       128
# 110          8.3     2001: A Space Odyssey              G  Mystery       160
# 149          8.2                   Rebecca      NOT RATED  Mystery       130
# 244          8.1            Shutter Island              R  Mystery       138
# 249          8.1                    Sleuth             PG  Mystery       138
# 264          8.1            Twelve Monkeys              R  Mystery       129
# 292          8.1  The Manchurian Candidate       APPROVED  Mystery       126
# 467          7.9              The 39 Steps        UNRATED  Mystery        86
# 583          7.8                 Dark City              R  Mystery       100
# ...

# %%
df1[df1.genre=='Mystery'].duration.sort_values()
# Out:
# 742     69
# 467     86
# 894     93
# 583    100
# 965    105
# 866    106
# 38     112
# 46     113
# 863    117
# 292    126
# 76     128
# 264    129
# 149    130
# 244    138
# 249    138
# 110    160
# Name: duration, dtype: int64

# %%
str1 = "Delhi"
