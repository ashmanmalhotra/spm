# %%
import pandas as pd

# %%
ofd = pd.read_csv('olympics.csv', skiprows=4)

# %%
ofd.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
ofd.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
ofd.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
ofd2 = pd.read_csv('olympics03.csv')

# %%
ofd2.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    NaN
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    NaN
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    NaN
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
ofd2.Gender.value_counts(dropna=False)
# Out:
# Men      21714
# Women     7490
# NaN         12
# Name: Gender, dtype: int64

# %%
ofd.Athlete.sort_values()
# Out:
# 651                    AABYE, Edgar
# 2849          AALTONEN, Arvo Ossian
# 2852          AALTONEN, Arvo Ossian
# 7716       AALTONEN, Paavo Johannes
# 7730       AALTONEN, Paavo Johannes
# 7773       AALTONEN, Paavo Johannes
# 7709       AALTONEN, Paavo Johannes
# 8563       AALTONEN, Paavo Johannes
# 28460              AAMODT, Ragnhild
# 3436               AANING, Alf Lied
# 19062         AARDENBURG, Willemien
# 22769             AARDEWIJN, Pepijn
# 22267          AARONES, Ann Kristin
# 3437                  AAS, Karl Jan
# 2601           AAS, Thomas Valentin
# 28134              ABAJO, Jose Luis
# 27691              ABAKUMOVA, Maria
# 27983           ABALMASAU, Aliaksei
# 28417                    ABALO, Luc
# 24202         ABANDA ETONG, Patrice
# 21538            ABARCA, Jose Maria
# 27125                 ABAS, Stephen
# 16390     ABASCAL GARCIA, Alejandro
# 16806    ABASCAL GOMEZ, Jose Manuel
# 26049             ABASSOVA, Tamilla
# 28418                   ABATI, Joel
# ...

# %%
ofd.sort_values(['Edition', 'City', 'Sport', 'Athlete']).head(10)[::-1]
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
#
#                         Event Event_gender   Medal
# 9              400m freestyle            M    Gold
# ...

# %%
ofd.Event=='freestyle'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
ofd[ofd.Discipline == 'Swimming']
# Out:
#           City  Edition     Sport Discipline                   Athlete  NOC  \
# 0       Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 1       Athens     1896  Aquatics   Swimming          HERSCHMANN, Otto  AUT
# 2       Athens     1896  Aquatics   Swimming         DRIVAS, Dimitrios  GRE
# 3       Athens     1896  Aquatics   Swimming        MALOKINIS, Ioannis  GRE
# 4       Athens     1896  Aquatics   Swimming        CHASAPIS, Spiridon  GRE
# 5       Athens     1896  Aquatics   Swimming     CHOROPHAS, Efstathios  GRE
# 6       Athens     1896  Aquatics   Swimming             HAJOS, Alfred  HUN
# 7       Athens     1896  Aquatics   Swimming          ANDREOU, Joannis  GRE
# 8       Athens     1896  Aquatics   Swimming     CHOROPHAS, Efstathios  GRE
# 9       Athens     1896  Aquatics   Swimming             NEUMANN, Paul  AUT
# 10      Athens     1896  Aquatics   Swimming         PEPANOS, Antonios  GRE
# ...

# %%
ofd.Discipline.value_counts()
# Out:
# Athletics          3448
# Rowing             2523
# Swimming           2439
# Artistic G.        2103
# Fencing            1547
# Football           1387
# Hockey             1325
# Shooting           1105
# Sailing            1061
# Basketball          940
# Canoe / Kayak F     912
# Handball            886
# Water polo          880
# Volleyball          862
# Boxing              842
# Cycling Track       692
# Wrestling Free.     591
# Wrestling Gre-R     549
# Weightlifting       548
# Judo                435
# Diving              356
# Baseball            335
# Eventing            313
# Jumping             312
# Archery             305
# Cycling Road        303
# Tennis              272
# Dressage            255
# Rugby               192
# Softball            180
# Modern Pentath.     174
# Synchronized S.     153
# Badminton           120
# Table Tennis        120
# Tug of War           94
# Rhythmic G.          93
# Canoe / Kayak S      90
# Taekwondo            80
# ...

# %%
ofd[(ofd.Discipline=='Swimming') | (ofd.Discipline=='Hockey')]
# Out:
#           City  Edition     Sport Discipline                  Athlete  NOC  \
# 0       Athens     1896  Aquatics   Swimming            HAJOS, Alfred  HUN
# 1       Athens     1896  Aquatics   Swimming         HERSCHMANN, Otto  AUT
# 2       Athens     1896  Aquatics   Swimming        DRIVAS, Dimitrios  GRE
# 3       Athens     1896  Aquatics   Swimming       MALOKINIS, Ioannis  GRE
# 4       Athens     1896  Aquatics   Swimming       CHASAPIS, Spiridon  GRE
# 5       Athens     1896  Aquatics   Swimming    CHOROPHAS, Efstathios  GRE
# 6       Athens     1896  Aquatics   Swimming            HAJOS, Alfred  HUN
# 7       Athens     1896  Aquatics   Swimming         ANDREOU, Joannis  GRE
# 8       Athens     1896  Aquatics   Swimming    CHOROPHAS, Efstathios  GRE
# 9       Athens     1896  Aquatics   Swimming            NEUMANN, Paul  AUT
# 10      Athens     1896  Aquatics   Swimming        PEPANOS, Antonios  GRE
# ...

# %%
chw = ofd[(ofd.Discipline=='Swimming') & (ofd.NOC=='CHN') & (ofd.Gender=='Women')]

# %%
chw.NOC.value_counts()
# Out:
# CHN    48
# Name: NOC, dtype: int64

# %%
ofd[(ofd.Discipline=='Swimming') & (ofd.NOC=='CHN') & (ofd.Gender=='Women')].count()
# Out:
# City            48
# Edition         48
# Sport           48
# Discipline      48
# Athlete         48
# NOC             48
# Gender          48
# Event           48
# Event_gender    48
# Medal           48
# dtype: int64

# %%
ofd.Athlete.str.contains('Alfred')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
ofd[ofd.Athlete.str.contains('Alfred')]
# Out:
#                         City  Edition          Sport       Discipline  \
# 0                     Athens     1896       Aquatics         Swimming
# 6                     Athens     1896       Aquatics         Swimming
# 73                    Athens     1896     Gymnastics      Artistic G.
# 74                    Athens     1896     Gymnastics      Artistic G.
# 85                    Athens     1896     Gymnastics      Artistic G.
# 100                   Athens     1896     Gymnastics      Artistic G.
# 261                    Paris     1900      Athletics        Athletics
# 271                    Paris     1900      Athletics        Athletics
# 312                    Paris     1900        Cricket          Cricket
# 319                    Paris     1900        Cricket          Cricket
# 391                    Paris     1900       Football         Football
# 429                    Paris     1900           Polo             Polo
# ...

# %%
ofd[ofd.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
res = ofd[(ofd.Edition>=1984) & (ofd.Edition<=2008)]

# %%
res = ofd[ofd.Medal=='Gold']
res.NOC.value_counts()
# Out:
# USA    2088
# URS     838
# GBR     498
# ITA     460
# GER     407
# HUN     400
# FRA     378
# SWE     347
# GDR     329
# AUS     293
# CHN     234
# NED     212
# JPN     206
# NOR     194
# RUS     192
# CUB     160
# ROU     155
# CAN     154
# DEN     147
# FRG     143
# YUG     143
# KOR     140
# IND     128
# FIN     124
# POL     103
# EUN      92
# ESP      92
# BEL      91
# TCH      80
# NZL      76
#        ...
# UZB       4
# AZE       4
# POR       4
# ALG       4
# SLO       4
# LTU       4
# CHI       3
# TPE       2
# DOM       2
# LAT       2
# MGL       2
# TUN       2
# SYR       1
# PAN       1
# ECU       1
# SUR       1
# VEN       1
# UGA       1
# COL       1
# ISR       1
# LUX       1
# ARM       1
# TRI       1
# HKG       1
# RU1       1
# BDI       1
# CRC       1
# MOZ       1
# PER       1
# UAE       1
# Name: NOC, Length: 96, dtype: int64

# %%
res.NOC.value_counts()
# Out:
# USA    2088
# URS     838
# GBR     498
# ITA     460
# GER     407
# HUN     400
# FRA     378
# SWE     347
# GDR     329
# AUS     293
# CHN     234
# NED     212
# JPN     206
# NOR     194
# RUS     192
# CUB     160
# ROU     155
# CAN     154
# DEN     147
# FRG     143
# YUG     143
# KOR     140
# IND     128
# FIN     124
# POL     103
# EUN      92
# ESP      92
# BEL      91
# TCH      80
# NZL      76
#        ...
# UZB       4
# AZE       4
# POR       4
# ALG       4
# SLO       4
# LTU       4
# CHI       3
# TPE       2
# DOM       2
# LAT       2
# MGL       2
# TUN       2
# SYR       1
# PAN       1
# ECU       1
# SUR       1
# VEN       1
# UGA       1
# COL       1
# ISR       1
# LUX       1
# ARM       1
# TRI       1
# HKG       1
# RU1       1
# BDI       1
# CRC       1
# MOZ       1
# PER       1
# UAE       1
# Name: NOC, Length: 96, dtype: int64

# %%
res.NOC.value_counts().head(3)
# Out:
# USA    2088
# URS     838
# GBR     498
# Name: NOC, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# # Plot
#   - plot(kind='bar')
#   - plot(kind='barh')
#   - plot(kind='line')
#   - plot(kind='pie')

# %%
firstolympics = ofd[ofd.Edition==1896]
firstolympics.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
firstolympics.Sport.value_counts().plot();

# %%
firstolympics.Sport.value_counts().plot(kind="bar");

# %%
firstolympics.Sport.value_counts().plot(kind="barh");

# %%
firstolympics.Sport.value_counts().plot(kind="pie");

# %%
ofd.Gender.value_counts().plot(kind="bar")

# %%
ofd[ofd.Medal=='Gold']['Gender'].value_counts().plot(kind="bar")

# %%
ofd[ofd.Medal=='Gold']['Gender'].value_counts().plot(kind="bar", color="brown")

# %% [markdown]
# # Figure size
# figsize((10, 3))

# %%
ofd[ofd.Medal=='Gold']['Gender'].value_counts().plot(kind="bar", figsize=(3, 2), color="brown")

# %%
ofd[ofd.Medal=='Gold']['Gender'].value_counts().plot(kind="bar", figsize=(3, 2), colormap="Pastel1")

# %%
import seaborn as sns

# %%
sns.countplot(x='Medal', data=ofd, hue="Gender");

# %%
ofd[ofd.NOC=='IND']['Discipline'].value_counts().plot(kind="bar")
